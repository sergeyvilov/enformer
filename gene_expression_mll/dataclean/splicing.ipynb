# %%
import pandas as pd
import os
import re

# %%
data_dir = '/s/project/mll/sergey/effect_prediction/outrider/input_data/fraser2/'

# %%
splicing_df = []

for leukemia_type in os.listdir(data_dir):
    file_name = data_dir + leukemia_type + '/results.tsv'
    if os.path.isfile(file_name):
        df = pd.read_csv(file_name, sep='\t')
        splicing_df.append(df)

# %%
splicing_df = pd.concat(splicing_df)
splicing_df = splicing_df[~splicing_df.sampleID.isna()]

# %%
splicing_df.rename(columns={'hgncSymbol':'geneHGNC', 'sampleID':'array_id'}, inplace=True)

# %%
matching_genes = pd.read_csv('/s/project/mll/sergey/effect_prediction/promoter_mutations/ensemble_to_HGNC_GRCh38.tsv.gz', sep='\t', 
                      header=None, names=['geneName', 'geneHGNC'], usecols=[0,1], skiprows=1)

matching_genes = matching_genes[~matching_genes.geneHGNC.isna()]

known_HGNC = matching_genes.geneHGNC.unique()

# %%
def is_multigene(x):
    
    n_hyphen = len(x.split('-'))
    
    if n_hyphen == 3:
        return x!='IGHV3-30-2'
    
    if n_hyphen == 1 or x in known_HGNC:
        return False
    
    return True

# %%
splicing_df.geneHGNC = splicing_df.geneHGNC.apply(lambda x: x.split('-') if is_multigene(x) else x)

splicing_df = splicing_df.explode('geneHGNC')

# %%
splicing_df = splicing_df.merge(matching_genes, how='left')

# %%
splicing_df[['array_id', 'geneHGNC', 'geneName']].to_csv('/s/project/mll/sergey/MLL_data/processed/significant_splicing.tsv', sep='\t', index=None)

# %%
splicing_df
# Out:
#          array_id seqnames      start        end width strand geneHGNC  \
# 0      MLL_126369     chr2  127451524  127453521  1998      +     GYPC
# 1      MLL_126369     chr5  179044112  179044514   403      -  HNRNPH1
# 2      MLL_126369     chr5  179044112  179044514   403      -  HNRNPH1
# 3      MLL_126369    chr17    7126557    7126801   245      +   ACADVL
# 4      MLL_126369     chrX  117738475  117739200   726      +   DOCK11
# ...           ...      ...        ...        ...   ...    ...      ...
# 45902   MUC_00705    chr19     861957     863091  1135      +      CFD
# 45903   MUC_00723    chr12   57926594   57926766   173      -    DCTN2
# 45904   MUC_00723    chr21   36253011   36259139  6129      -    RUNX1
# 45905   MUC_00723    chr19   16254585   16259533  4949      +    HSH2D
# 45906   MUC_00723     chr1   36752872   36754660  1789      +   THRAP3
#
#           type pValue   padjust  ... COUNT_OVERLAPS GENE_COUNTS_FILE  \
# 0      jaccard    0.0  0.000003  ...           True              NaN
# 1      jaccard    0.0  0.000055  ...           True              NaN
# 2      jaccard    0.0  0.000055  ...           True              NaN
# 3      jaccard    0.0  0.002315  ...           True              NaN
# 4      jaccard    0.0  0.004604  ...           True              NaN
# ...        ...    ...       ...  ...            ...              ...
# 45902  jaccard    0.0  0.035717  ...           True              NaN
# 45903  jaccard    0.0       0.0  ...           True              NaN
# 45904  jaccard    0.0       0.0  ...           True              NaN
# 45905  jaccard    0.0  0.000015  ...           True              NaN
# 45906  jaccard    0.0  0.000015  ...           True              NaN
#
#       ANNOTATION isExternal                 potentialImpact  causesFrameshift  \
# 0            NaN      False    annotatedIntron_reducedUsage          unlikely
# 1            NaN      False  annotatedIntron_increasedUsage          unlikely
# 2            NaN      False  annotatedIntron_increasedUsage          unlikely
# 3            NaN      False                  exonElongation            likely
# 4            NaN      False                  exonElongation          unlikely
# ...          ...        ...                             ...               ...
# 45902        NaN      False    annotatedIntron_reducedUsage          unlikely
# 45903        NaN      False    annotatedIntron_reducedUsage          unlikely
# 45904        NaN      False    annotatedIntron_reducedUsage          unlikely
# 45905        NaN      False    annotatedIntron_reducedUsage          unlikely
# 45906        NaN      False    annotatedIntron_reducedUsage          unlikely
#
#       UTR_overlap blacklist distNearestGene         geneName
# 0              no     False             NaN  ENSG00000136732
# 1              no     False             NaN  ENSG00000284254
# 2              no     False             NaN  ENSG00000169045
# 3              no     False             NaN  ENSG00000072778
# 4              no     False             NaN  ENSG00000147251
# ...           ...       ...             ...              ...
# 45902          no     False             NaN  ENSG00000197766
# 45903          no     False             NaN  ENSG00000175203
# 45904          no     False             NaN  ENSG00000159216
# 45905      5'-UTR     False             NaN  ENSG00000196684
# 45906          no     False             NaN  ENSG00000054118
#
# [45907 rows x 62 columns]
